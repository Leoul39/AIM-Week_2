# %%
import os
import pandas as pd
os.chdir('..')
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from scripts.utils import *

# %% [markdown]
# * First we have to load the data we brought from the database using sqlalchemy an make some basic EDA

# %%
data= DataLoader()
df=data.load_data_using_sqlalchemy()
df.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %%
df.columns
# Out:
# Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'TCP DL Retrans. Vol (Bytes)', 'TCP UL Retrans. Vol (Bytes)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'HTTP DL (Bytes)', 'HTTP UL (Bytes)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)', 'Dur. (ms).1', 'Handset Manufacturer',
#        'Handset Type', 'Nb of sec with 125000B < Vol DL',
#        'Nb of sec with 1250B < Vol UL < 6250B',
#        'Nb of sec with 31250B < Vol DL < 125000B',
#        'Nb of sec with 37500B < Vol UL',
#        'Nb of sec with 6250B < Vol DL < 31250B',
# ...

# %%
#Let's plot the amount of null values in a bar graph
plot_null(df)

# %% [markdown]
# * From the above bar graph, we can see that `Nb of sec with 37500B < Vol UL` column has the highest amount of null values with around 130,000 null values. The application download and upload columns have almost no null values so it eases our analysis.
# * Now we load the overview data that is sorted with the identifier count

# %%
overview=DataOverview(df)
apps=['Social Media','Google','Email','Youtube','Netflix','Gaming','Other']
overview_data=overview.overview_data(apps,'Bearer Id')

# %% [markdown]
# * Since we filled the dataset with the mean value, there will be no null values

# %%
overview_data.isnull().sum()
# Out:
# Duration (s)                  0
# Social Media (Total in MB)    0
# Google (Total in MB)          0
# Email (Total in MB)           0
# Youtube (Total in MB)         0
# Netflix (Total in MB)         0
# Gaming (Total in MB)          0
# Other (Total in MB)           0
# Total UL (in MB)              0
# Total DL (in MB)              0
# Total Volume (in MB)          0
# Bearer Id                     0
# dtype: int64

# %%
overview_data.describe()
# Out:
#         Duration (s)  Social Media (Total in MB)  Google (Total in MB)  \
# count  107265.000000               107265.000000         107265.000000
# mean      145.935549                    2.546834             10.876958
# std       186.351794                    1.907853              7.541444
# min         7.142000                    0.001563              0.040330
# 25%        70.411000                    1.210649              5.939246
# 50%       102.450000                    2.302912              9.583294
# 75%       172.799000                    3.306564             13.206946
# max     18553.754000                   43.374779            152.191852
#
#        Email (Total in MB)  Youtube (Total in MB)  Netflix (Total in MB)  \
# count        107265.000000          107265.000000          107265.000000
# mean              3.147036              31.543012              31.521789
# std               2.221693              21.286493              21.282066
# ...

# %% [markdown]
# * Some key points that can be noticed from the .describe data:
#    1. the `Gaming` and `Other` columns beat the other application columns by a fair margin with both of them having a mean around 600MB. This can be attributed to the fact that most gaming application involve downloading large files for updates and patches.
#    2. On top of that, they have a very high standard deviation. High standard deviation indicates that the values in the dataset deviate further from the average value. This also shows that there might be outliers present.
#    3. On the `Duration` column, using the maximum and median value,we can see that most of the users spend well below the median time spent.
#    4. Surprisingly, the data usage from `Social Media` and `Youtube` are low compared to `Gaming` data usage.
#    5. As a measure for dispersion we can use the standard deviation value. The `Gaming` and `Other` column also have very high std values. This means that some values have huge variation from the mean value. this also shows that there might be an outlier on those columns.
#
# * Insights
#    1. Users appear to prefer interactive activities like gaming rather than passive content consumption.
#    2. The intensive data volume in the gaming column represent more revenue streams for app developers and this can also indicate that investment in gaming-related content or services may yield higher financial returns.
#    3. Higher data usage in gaming can also imply that users spend more time on gaming apps than social medias. Companies can leverage this information to enhance user experiences. This can be done by changing the market strategies to target this specific user segments by making the download speed faster to engage the users more.
#    4. Since more data usage means more time spent and more time spent means more money made, the company has to do interesting marketing campaigns to increase the usage of these social medias. Partnering with social media influencers can also promote the brand. Offering exclusive deals and discounts can also ease the access to these social medias.

# %%
apps=['Social Media','Google','Email','Youtube','Netflix','Gaming','Other']
plot_corr(overview_data,apps)
# Out:
# <Axes: >

# %% [markdown]
# * Key finding from the correlation:
#   1. The highest relationship was seen by netfix and youtube users. This implies the fairly equal consumption of youtube videos and netflix movies.
#   2. The least relationship was seen between `gaming` and `Other` users. This shows that users who use `gaming` apps are not often seen using the apps mentioned in `Other`

# %%
sub=Subtask(df)
sub.subtasks()
# Out:
# The top 10 handsets used by the customers are:
# Handset Type
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Samsung Galaxy A5 Sm-A520F       3724
# Name: count, dtype: int64
# The top 3 handset manufacturers are:
# Handset Manufacturer
# Apple      59565
# Samsung    40839
# Huawei     34423
# Name: count, dtype: int64
# The top 5 handsets for Apple are:
# Handset Type
# Apple iPhone 6S (A1688)    9419
# Apple iPhone 6 (A1586)     9023
# Apple iPhone 7 (A1778)     6326
# Name: count, dtype: int64
# The top 5 handsets for Samsung are:
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4520
# Samsung Galaxy A5 Sm-A520F      3724
# Samsung Galaxy J5 (Sm-J530)     3696
# ...

# %% [markdown]
# * Some observations from the above data
#   1. `Huawei B528S-23A` has the highest appearance in the data with almost 19500 times. But as a whole handset manufacturer, `Apple` produces many of the handesets used in this dataset.
#   2. For each of the top 3 handset manufacturers the top handset used by the users are:
#        - for `Apple`- `Apple iPhone 6S`
#        - for `Samsung`- `Samsung Galaxy S8`
#        - for `Huawei`- `Huawei B528S-23A`
#   3.

# %%
dr=df[df['Handset Manufacturer']=='Samsung']
dr['Handset Type'].value_counts().head()
# Out:
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4520
# Samsung Galaxy A5 Sm-A520F      3724
# Samsung Galaxy J5 (Sm-J530)     3696
# Samsung Galaxy J3 (Sm-J330)     3484
# Samsung Galaxy S7 (Sm-G930X)    3199
# Name: count, dtype: int64

# %%
#Computes the top 5 decile class
decile_class(overview_data,'Duration (s)','Total Volume (in MB)')
# Out:
#               Total Volume (in MB)  Total Volume (in GB)
# Decile_Class
# 0                     1.156307e+07          11563.065289
# 1                     1.273187e+07          12731.867620
# 2                     1.152279e+07          11522.790776
# 3                     1.401931e+07          14019.308745
# 4                     2.424614e+07          24246.140734

# %% [markdown]
# * Some observations
#    1. Since the decile class is made from total duration, users who spend more time tend to also have high data usage as expected.
#    2. Users in the 3rd decile class skew the expected data usage by having less data usage than the 2nd decile class. Except that, the data usage and the time spent are directly proportional.
#    3. There is a huge jump from the 4th decile class to the 5th decile class. This indicates that users on the higher end of the Total time spent consume a considerably large amount of Data.

# %%
pca(overview_data);
